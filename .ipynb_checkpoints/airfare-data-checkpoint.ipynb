# %% [markdown]
# # 0. Introduction

# %% [markdown]
# This project is to compare airfare prices overall trends from 1995 to 2021, then focus on the differences between Q1 of 2020 and 2021.

# %% [markdown]
# # 1. Import Libraries

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # 2. Airfare from 1995 - 2021

# %% [markdown]
# ## annual_fares.csv Data Information
#
# Report of the Annual U.S. Domestic Average Itinerary Fare in Current and Constant Dollars downloaded from BTS.
#
# **Source:** Bureau of Transportation Statistics
#
# *Rate calculated using Bureau of Labor Statistics Consumer Price Index.
#
# **Itinerary Fares:** BTS reports average fares based on domestic itinerary fares. Itinerary fares consist of round-trip fares, unless the customer does not purchase a return trip. In that case, the one-way fare is included. Fares are based on the total ticket value, which consists of the price charged by the airlines plus any additional taxes and fees levied by an outside entity at the time of purchase. Fares include only the price paid at the time of the ticket purchase and do not include fees for optional services, such as baggage fees. Averages do not include frequent-flyer or “zero fares.”  Constant 2021 dollars are used for inflation adjustment.
#
# Note: Percent change based on unrounded numbers
#
# [Report found here](https://www.bts.gov/content/annual-us-domestic-average-itinerary-fare-current-and-constant-dollars)

# %% [markdown]
# ## Import CSV

# %%
# Use pandas to read the csv

annual_fares = pd.read_csv('annual_fares.csv')

# %% [markdown]
# ## Check Data for Whitespace and Conversion

# %%
# Check output and headings

annual_fares
# Out:
#     Year  Inflation_Adjusted_Fare  Average_Fare
# 0   1995                      518           292
# 1   1996                      482           277
# 2   1997                      467           287
# 3   1998                      495           309
# 4   1999                      530           324
# 5   2000                      527           339
# 6   2001                      521           321
# 7   2002                      473           312
# 8   2003                      459           315
# 9   2004                      452           305
# 10  2005                      413           307
# 11  2006                      428           329
# 12  2007                      410           325
# 13  2008                      414           346
# 14  2009                      390           310
# 15  2010                      398           336
# 16  2011                      422           364
# 17  2012                      430           375
# 18  2013                      430           382
# 19  2014                      434           392
# 20  2015                      437           377
# 21  2016                      398           349
# 22  2017                      378           348
# 23  2018                      366           350
# 24  2019                      364           355
# 25  2020                      343           292
# 26  2021                      260           260

# %%
# Check headers to rename without whitespace if needed

annual_fares.columns
# Out:
# Index(['Year', 'Inflation_Adjusted_Fare', 'Average_Fare'], dtype='object')

# %% [markdown]
# ## Graph Fares Over Time

# %%
# LINE GRAPH OF AIRFARE OVER TIME


# Adjust size
plt.figure(figsize=(9,7))


# Change color palette
plt.style.use('bmh')


# Title
plt.title('Average Airfare Price per Ticket in USD', pad=10, fontdict={'fontweight': 'bold', 'fontsize': 18})


# X and Y Axis
x = annual_fares.Year
y = annual_fares.Average_Fare
y2 = annual_fares.Inflation_Adjusted_Fare
plt.xlabel('Year')
plt.ylabel('USD') 


# Information to Graph
plt.plot(x, y, marker = '.', label = 'Fares in USD')
plt.plot(x, y2, marker = '.', label = "Fares Adjusted for Inflation")


# Show legend
plt.legend()


plt.show()

# %% [markdown]
# ## Notes on Findings
#
# The highest average ticket price, adjusted for inflation, occurred in 1999, with a fare of `$324` and adjusted fare of `$530`.
#
# The highest average ticket price, not adjusted, occurred in 2014 with a fare of `$392`.
#
# The lowest averge ticket price in the last 26 years, both in adjusted and not adjusted, occurred in Q1 of 2021 with a fare of `$260`.

# %%
# Use pandas to read the csv

dollar = pd.read_csv('dollar_adjusted.csv')



# LINE GRAPH OF AIRFARE OVER TIME


# Adjust size
plt.figure(figsize=(9,7))


# Change color palette
plt.style.use('bmh')


# Title
plt.title('Adjusted Buying Power of $1 USD, 1995 - 2021', pad=10, fontdict={'fontweight': 'bold', 'fontsize': 18})


# X and Y Axis labels
plt.xlabel('Year')
plt.ylabel('USD') 


# Information to Graph
plt.plot(dollar.Year, dollar.Adjusted_Dollar, label = "One Dollar USD Inflation")

# Show legend
plt.legend()


plt.show()

# %%
usd_start = 1.82
usd_end = 1.05

usd_rate = ((usd_start - usd_end) / usd_start) * 100


adj_fare_start = 518
adj_fare_end = 260

adj_fare_rate = ((adj_fare_start - adj_fare_end) / adj_fare_start) * 100

# %%
# Adjust size
plt.figure(figsize=(9,7))


fig, ax = plt.subplots()

x = annual_fares.Year
y = annual_fares.Inflation_Adjusted_Fare

plt.plot(x, y, marker = '.', label = "Fares Adjusted for Inflation")


z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x, p(x),'r--')

plt.show()

# %% [markdown]
# # 3. Airfare from Q1 of 2020 and 2021

# %% [markdown]
# ## Q1_2020.csv and Q1_2021.csv Data Information
#
# **Source:** Bureau of Transportation Statistics, Airline Origin & Destination Survey (10% Sample), DB1B_Ticket where bulk fare equals zero, itinerary fare is greater than or equal to fifty dollars and itinerary yield is less than or equal to three dollars.
#
# **Itinerary Fare:** Average fares are based on domestic itinerary fares, round-trip or one-way for which no return is purchased. Fares are based on the total ticket value which consists of the price charged by the airlines plus any additional taxes and fees levied by an outside entity at the time of purchase. Fares include only the price paid at the time of the ticket purchase and do not include other fees, such as baggage fees, paid at the airport or onboard the aircraft. Averages do not include frequent-flyer or 'zero fares' or a few abnormally high reported fares. Airports* ranked by U.S. originating domestic passengers in 2020.
#
# [BTS Website](https://www.transtats.bts.gov/AverageFare/)

# %% [markdown]
# ## Import CSVs

# %%
# Use pandas to read the csv

airfare_2020 = pd.read_csv('Q1_2020.csv')
airfare_2021 = pd.read_csv('Q1_2021.csv')

# %% [markdown]
# ## Check Data for Whitespace and Conversion

# %%
# Check chart and headings

airfare_2020
# Out:
#      2020_Passenger_Rank                             Airport_Name   \
# 0                      1                 Los Angeles International
# 1                      2  Hartsfield-Jackson Atlanta International
# 2                      3                      Denver International
# 3                      4              Chicago O'Hare International
# 4                      5           Dallas/Fort Worth International
# ..                   ...                                       ...
# 424                  424                                Sand Point
# 425                  426                   Middle Georgia Regional
# 426                  426                          Unalaska Airport
# 427                  428         Wokal Field Glasgow Valley County
# 428                  429                               Toksook Bay
#
#          City_Name   State_Name    Average_Fare   Sample_Size
# 0       Los Angeles           CA          328.17      513,309
# 1           Atlanta           GA          359.58      415,199
# 2            Denver           CO          295.96      412,135
# 3    Chicago-O'Hare           IL          332.05      401,710
# 4        Dallas-DFW           TX          400.52      351,090
# ..              ...          ...             ...           ...
# 424       Sandpoint           AK          729.00            4
# 425           Macon           GA          426.00            3
# 426        Unalaska           AK         1074.33            3
# 427         Glasgow           MT          332.00            2
# 428         Toksook           AK          561.00            1
#
# [429 rows x 6 columns]

# %%
# Check headers to rename without whitespace

airfare_2020.columns
# Out:
# Index(['2020_Passenger_Rank', ' Airport_Name ', ' City_Name ', ' State_Name ',
#        ' Average_Fare ', ' Sample_Size '],
#       dtype='object')

# %%
# Remove column header whitespce

airfare_2020.columns = airfare_2020.columns.str.strip()
airfare_2021.columns = airfare_2021.columns.str.strip()

# %%
# Check that columns are corrected

print(airfare_2020.columns)
print(airfare_2021.columns)
# Out:
# Index(['2020_Passenger_Rank', 'Airport_Name', 'City_Name', 'State_Name',
#        'Average_Fare', 'Sample_Size'],
#       dtype='object')
# Index(['2020_Passenger_Rank', 'Airport_Name', 'City_Name', 'State_Name',
#        'Average_Fare', 'Sample_Size'],
#       dtype='object')

# %%
# Assign variables

air_ss = airfare_2020.Sample_Size
air_ss21 = airfare_2021.Sample_Size


# Delete Whitespace in Sample_Size columns

air_ss = air_ss.str.strip()
air_ss21 = air_ss21.str.strip()


# Delete -NaN in 2021 list

air_ss21[:] = ['0' if x == '-NaN' else x for x in air_ss21]


# Convert from string to numeric

air_ss = air_ss.str.replace(',', '').astype(int)
air_ss21 = air_ss21.str.replace(',', '').astype(int)

# %%
# GRAPH FOR ALL AIRPORTS, Q1 IN 2020 AND 2021


# Adjust size
plt.figure(figsize=(9,7))


# Title
plt.title('Average Airfare from All U.S. Airports', pad=10, fontdict={'fontweight': 'bold', 'fontsize': 18})


# X and Y Axis labels
plt.xlabel('Sample Size (10% of all Tickets)')
plt.ylabel('Average Ticket Price, USD') 


# Information to graph
x = air_ss
y = airfare_2020.Average_Fare

x2 = air_ss21
y2 = airfare_2021.Average_Fare


# Scatter Plot
plt.plot(x, y, 'o', alpha=0.5, label='Fares in Q1 2020')
plt.plot(x2, y2, 'o', alpha=0.5, label='Fares in Q1 2021')


# Show legend
plt.legend()


plt.show()

# %%
#GRAPH FOR BUSIEST 100 AIRPORTS, Q1 IN 2020 AND 2021

# Adjust size
plt.figure(figsize=(9,7))


# Title
plt.title('Average Airfare from 100 Busiest U.S. Airports', pad=10, fontdict={'fontweight': 'bold', 'fontsize': 18})


# X and Y Axis labels
plt.xlabel('Sample Size (10% of all Tickets)', labelpad=20)
plt.ylabel('Average Ticket Price, USD', labelpad=20) 


# Information to graph
x = air_ss[:100]
y = airfare_2020.Average_Fare[:100]

x2 = air_ss21[:100]
y2 = airfare_2021.Average_Fare[:100]


# Scatter Plot
plt.plot(x, y, 'go', alpha=0.5, label='Fares in Q1 2020')
plt.plot(x2, y2, 'bo', alpha=0.5, label='Fares in Q1 2021')


# Show legend
plt.legend()


plt.show()

# %% [markdown]
# ### Bar Graphs

# %%
# BAR GRAPH FOR FIVE BUSIEST AIRPORTS


# Information to Graph
labels = airfare_2020['Airport_Name'][:5]
y = airfare_2020['Average_Fare'][:5]
y2 = airfare_2021['Average_Fare'][:5]


# Numpy for evenly spaced values
x = np.arange(len(labels))


# Bar width
width = 0.35


# Set figure and axes objects, increase graph size
fig, ax = plt.subplots(figsize=(18,10))


# Bars 
rects1 = ax.bar(x - width/2, y, width, color="#0081A7", label="Q1 Airfare 2020")
rects2 = ax.bar(x + width/2, y2, width, color="#F07167", label="Q1 Airfare 2021")


# Title
ax.set_title('Five Busiest Airports Average Ticket Price', pad=20, fontdict={'fontweight': 'bold', 'fontsize': 22})


# X-Axis
plt.xticks(x, labels, horizontalalignment='center')


# Y-Axis
ax.set_ylabel('Average Ticket Price USD')


# Add labels and annotations to bar containers
ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)


# Add Legend
ax.legend()


plt.show()
